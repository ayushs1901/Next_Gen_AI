# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushs1901/Next_Gen_AI/blob/main/Gen_AI_Lec_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("headbrain.csv")

# %%
df.shape
# Out:
# (237, 4)

# %%
df.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
X = df['Head Size(cm^3)'].values
y = df['Brain Weight(grams)'].values

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,y)
plt.show()

# %%
mean_x = np.mean(X)
mean_y = np.mean(y)

# %%
mean_x, mean_y
# Out:
# (np.float64(3633.9915611814345), np.float64(1282.873417721519))

# %%
numer = 0
denom = 0
n = len(X)

for i in range(n):
  numer += (y[i] - mean_y) * (X[i] - mean_x)
  denom += (X[i] - mean_x) ** 2

slope = numer / denom
intercept = mean_y - slope * mean_x
print("Slope :",slope)
print("Intercept :",intercept)
# Out:
# Slope : 0.26342933948939945
# Intercept : 325.57342104944223

# %%
predictions = []
for i in range(n):
  y_pred = slope * X[i] + intercept
  predictions.append(int(y_pred))

# %%
print("Prediction:",predictions[:5])
print("Actual:",y[:5])
# Out:
# Prediction: [1514, 1310, 1448, 1320, 1425]
# Actual: [1530 1297 1335 1282 1590]

# %%
plt.figure(figsize=(10,6))
plt.scatter(X,y)
plt.plot(X, predictions, 'r')
plt.show()

# %%
error = 0
for i in range(n):
  error += (predictions[i] - y[i]) ** 2

mse = error /n
print("MSE :",mse)
print("RMSE :",np.sqrt(mse))
# Out:
# MSE : 5202.9029535864975
# RMSE : 72.13115106239812

# %% [markdown]
# # Machine Learning starts
# Gradient descent

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
X = np.reshape(X, (-1,1))
y = np.reshape(y, (-1,1))

minmax = MinMaxScaler()
scaled_X = minmax.fit_transform(X)
scaled_y = minmax.fit_transform(y)

# %%
scaled_X[:5]
# Out:
# array([[0.88406512],
#        [0.50222003],
#        [0.7602368 ],
#        [0.52146029],
#        [0.71879625]])

# %%
def gradiant_descent(epochs, alpha):
  slope, inter = 0,0
  for i in range(epochs):
    y_pred = scaled_X * slope + inter
    loss = y_pred - scaled_y
    gradSlope = (2/n) * np.dot(loss.T, scaled_X)
    gradInter = (2/n) * np.sum(loss)
    slope = slope - gradSlope * alpha
    inter = inter - gradInter * alpha
  return slope, inter

# %%
epochs = 8000
alpha = 0.01
slope, inter = gradiant_descent(epochs, alpha)
print("Slope :",slope)
print("Inter :", inter)
# Out:
# Slope : [[0.77698429]]
# Inter : 0.13192040975853606

# %%
predictions = []
for i in range(n):
  y_pred = slope[0] [0] * scaled_X[i] + inter
  predictions.append(y_pred)


plt.figure(figsize=(10,6))
plt.scatter(scaled_X,scaled_y)
plt.plot(scaled_X, predictions, 'r')
plt.show()
