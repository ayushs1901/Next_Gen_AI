# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushs1901/Next_Gen_AI/blob/main/Gen_ai_Lac_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
# 4 things to do in nltk
# --Tokenization____Stopword removal

# %%
nltk.download("punkt")
nltk.download("stopwords")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer

# %%
raw_text = "I am learning Python programming, python is greatest language..!!"

# %%
raw_text = raw_text.lower()
print("After lowercase:",raw_text)
# Out:
# After lowercase: i am learning python programming, python is greatest language..!!

# %%
raw_text = raw_text.strip()
print("After lowercase:",raw_text)
# Out:
# After lowercase: i am learning python programming, python is greatest language..!!

# %%
print(raw_text.split())
# Out:
# ['i', 'am', 'learning', 'python', 'programming,', 'python', 'is', 'greatest', 'language..!!']

# %%
tokens = word_tokenize(raw_text)
print("Tokens:",tokens)
# Out:
# Tokens: ['i', 'am', 'learning', 'python', 'programming', ',', 'python', 'is', 'greatest', 'language', '..', '!', '!']

# %%
stopwords.words("english")
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
english_stopwords = stopwords.words("english")

# %%
filtered_tokens = []
for word in tokens:
  if word not in english_stopwords:
    filtered_tokens.append(word)

print("filtered Tokens:",filtered_tokens)
# Out:
# filtered Tokens: ['learning', 'python', 'programming', ',', 'python', 'greatest', 'language', '..', '!', '!']

# %%
import string
punctuations = string.punctuation
print("Puntuation available: ",punctuations)
# Out:
# Puntuation available:  !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
clean_tokens=[word for word in filtered_tokens if word not in punctuations]
print("After removing punctuations:",clean_tokens)
# Out:
# After removing punctuations: ['learning', 'python', 'programming', 'python', 'greatest', 'language', '..']

# %%
stem = PorterStemmer()
stem.stem("bought")
# Out:
# 'bought'

# %%
wnet = WordNetLemmatizer()
wnet.lemmatize("playing", "v")
# Out:
# 'play'

# %%
lemmatized_tokens = []
for word in clean_tokens:
  lemmatized_tokens.append(wnet.lemmatize(word,"v"))

print("Lemmatized Tokens:",lemmatized_tokens)
# Out:
# Lemmatized Tokens: ['learn', 'python', 'program', 'python', 'greatest', 'language', '..']

# %%
final_tokens = []
for word in lemmatized_tokens:
  if word.isalpha():
    final_tokens.append(word)

print('Final Tokens: ',final_tokens)
# Out:
# Final Tokens:  ['learn', 'python', 'program', 'python', 'greatest', 'language']

# %%
cleaned_text = " ".join(final_tokens)
print("Cleaned Text:",cleaned_text)
# Out:
# Cleaned Text: learn python program python greatest language
